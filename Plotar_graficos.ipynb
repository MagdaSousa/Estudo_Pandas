# %% [markdown]
# <a href="https://colab.research.google.com/github/MagdaSousa/Estudo_Pandas/blob/master/Plotar_graficos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('dark_background')

# %%
plt.rcParams['figure.figsize']=(20,7)

# %%
df = pd.read_csv('titanic_train.csv')

# %%
df.head(3)
# Out:
#    Unnamed: 0  PassengerId  Survived  Sex  ...  Title_4  Emb_1  Emb_2  Emb_3
# 0           0            1         0    1  ...        0      0      0      1
# 1           1            2         1    0  ...        0      1      0      0
# 2           2            3         1    0  ...        1      0      0      1
#
# [3 rows x 17 columns]

# %%
df.shape
# Out:
# (792, 17)

# %%
plt.plot(df.Age,'*-')
plt.title('INFORMAÇÕES DOS PASSAGEIROS DO TITANIC')
plt.xlabel('Passageiros',size =14)
plt.ylabel('Idade',size =14)
plt.show()

# %%
plt.plot(df.Age,'*-r')
plt.show()

# %%
plt.plot(df.Age,'-')
plt.show()

# %% [markdown]
# plotando com pandas

# %%
df.Age.plot()
plt.show()

# %%
df.plot()

# %% [markdown]
# scatter plot

# %%
df.head(2)
# Out:
#    Unnamed: 0  PassengerId  Survived  Sex  ...  Title_4  Emb_1  Emb_2  Emb_3
# 0           0            1         0    1  ...        0      0      0      1
# 1           1            2         1    0  ...        0      1      0      0
#
# [2 rows x 17 columns]

# %%
plt.scatter(df.PassengerId,df.Age,color='r',marker='>')
plt.show()

# %%
df.head(2)
# Out:
#    Unnamed: 0  PassengerId  Survived  Sex  ...  Title_4  Emb_1  Emb_2  Emb_3
# 0           0            1         0    1  ...        0      0      0      1
# 1           1            2         1    0  ...        0      1      0      0
#
# [2 rows x 17 columns]

# %%
df.Age.describe()
# Out:
# count    792.000000
# mean       0.368244
# std        0.162994
# min        0.008375
# 25%        0.275000
# 50%        0.350000
# 75%        0.437500
# max        1.000000
# Name: Age, dtype: float64

# %%
df.Age.hist()
plt.savefig('nome.png',transparent = True)
plt.show()
